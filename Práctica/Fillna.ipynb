# %% [markdown]
# # Handling missing values

# %% [markdown]
# ## fillna fills NaN values using the specified method
#
# ## By default: `DataFrame.fillna(value=None, method=None, axis=None, inplace=False, limit=None)`

# %% [markdown]
# ## value:
# It is a value that is used to fill the null values.
# scalar, dict, Series, or DataFrame.

# %% [markdown]
# ##Method:
#
# Method to use for filling holes in reindexed Series.
#
# **pad / ffill**: propagate last valid observation forward to next.
# (Top To Bottom)
#
# **backfill / bfill**: use next valid observation to fill gap.
# (Bottom To Top)

# %% [markdown]
# ##axis:
# axis takes int or string value for
#
# **rows**: Input can be 0 or  ‘index’.
#
# **Columns**: Input can be 1 or  ‘columns’.

# %% [markdown]
# ## inplace:
# It is a boolean which makes the changes in the data frame itself if True.

# %% [markdown]
# ##limit:
# int, default None
#
# If the method is specified, this is the maximum number of consecutive NaN values to forward/backward fill.
#
# Must be greater than 0 if not None.

# %%
import pandas as pd

# %%
data = pd.read_csv('data_m.csv', skipfooter = 1, engine = 'python')
data
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0    NaN
# 1   Aadhya    NaN     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0    NaN
# 4   Parshv   90.0     AC
# 5   Mittal    NaN     BA
# 6  Archana   82.0     BB

# %% [markdown]
# ## Fill all NaN values with 0

# %%
data.fillna(value = 0)
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0      0
# 1   Aadhya    0.0     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0      0
# 4   Parshv   90.0     AC
# 5   Mittal    0.0     BA
# 6  Archana   82.0     BB

# %% [markdown]
# ## Fill all NaN values with mean value

# %%
df = pd.DataFrame({'City': ['Tonalá', 'Guadalajara', 'Nueva Escocia', 'Nueva York',
                    'Delhi', 'San Luis Potosí'],
                   'Temp':[34.0,None,None,40.0,None, 45.0]})
df

df.to_csv('data_new.csv', index = False)

# %%
df.fillna(value = df['Temp'].mean())
# Out:
#               City       Temp
# 0           Tonalá  34.000000
# 1      Guadalajara  39.666667
# 2    Nueva Escocia  39.666667
# 3       Nueva York  40.000000
# 4            Delhi  39.666667
# 5  San Luis Potosí  45.000000

# %% [markdown]
# ## Fill all NaN elements in columns 'Marks' and 'Grades' with 97 and 'AA' respectively

# %%
data.fillna({'Marks':97, 'Grades':'AA'})
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0     AA
# 1   Aadhya   97.0     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0     AA
# 4   Parshv   90.0     AC
# 5   Mittal   97.0     BA
# 6  Archana   82.0     BB

# %% [markdown]
# ## Propagate non-values foward (fill them with the last observasion from top to bottom)

# %%
df = pd.read_csv('data_new.csv')
df
# Out:
#               City  Temp
# 0           Tonalá  34.0
# 1      Guadalajara   NaN
# 2    Nueva Escocia   NaN
# 3       Nueva York  40.0
# 4            Delhi   NaN
# 5  San Luis Potosí  45.0

# %%
df.fillna(method = 'ffill')
# Out:
# <ipython-input-33-67e2dcd61a82>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'ffill')
#               City  Temp
# 0           Tonalá  34.0
# 1      Guadalajara  34.0
# 2    Nueva Escocia  34.0
# 3       Nueva York  40.0
# 4            Delhi  40.0
# 5  San Luis Potosí  45.0

# %%
# También se puede hacer esto
df.fillna(method = 'pad')
# Out:
# <ipython-input-34-af91d5be147d>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'pad')
#               City  Temp
# 0           Tonalá  34.0
# 1      Guadalajara  34.0
# 2    Nueva Escocia  34.0
# 3       Nueva York  40.0
# 4            Delhi  40.0
# 5  San Luis Potosí  45.0

# %%
# Las 2 formas anteriores no se recomiendan, es mejor usar esta
df.ffill()
# Out:
#               City  Temp
# 0           Tonalá  34.0
# 1      Guadalajara  34.0
# 2    Nueva Escocia  34.0
# 3       Nueva York  40.0
# 4            Delhi  40.0
# 5  San Luis Potosí  45.0

# %%
# Por default, el relleno se hace por filas
df.ffill(axis = 'index')
# Out:
#               City  Temp
# 0           Tonalá  34.0
# 1      Guadalajara  34.0
# 2    Nueva Escocia  34.0
# 3       Nueva York  40.0
# 4            Delhi  40.0
# 5  San Luis Potosí  45.0

# %%
# Pero se puede hacer por columnas, en este caso de izquierda a derecha
df.ffill(axis = 'columns')
# Out:
#               City           Temp
# 0           Tonalá           34.0
# 1      Guadalajara    Guadalajara
# 2    Nueva Escocia  Nueva Escocia
# 3       Nueva York           40.0
# 4            Delhi          Delhi
# 5  San Luis Potosí           45.0

# %% [markdown]
# ## Propagate non-values backwards (fill them with the last observasion from bottom to top)

# %%
df.fillna(method = 'backfill')
# Out:
# <ipython-input-37-edd69a4caa35>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'backfill')
#               City  Temp
# 0           Tonalá  34.0
# 1      Guadalajara  40.0
# 2    Nueva Escocia  40.0
# 3       Nueva York  40.0
# 4            Delhi  45.0
# 5  San Luis Potosí  45.0

# %%
# También se puede hacer de esta manera
df.fillna(method = 'bfill')
# Out:
# <ipython-input-38-ce2c89e36dd7>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'bfill')
#               City  Temp
# 0           Tonalá  34.0
# 1      Guadalajara  40.0
# 2    Nueva Escocia  40.0
# 3       Nueva York  40.0
# 4            Delhi  45.0
# 5  San Luis Potosí  45.0

# %%
# Las 2 formas anteriores no se recomiendan, es mejor usar esta
df.bfill()
# Out:
#               City  Temp
# 0           Tonalá  34.0
# 1      Guadalajara  40.0
# 2    Nueva Escocia  40.0
# 3       Nueva York  40.0
# 4            Delhi  45.0
# 5  San Luis Potosí  45.0

# %%
# Por default, el relleno se hace por filas
data.bfill(axis = 'index')
# Out:
#       Name  Marks Grades
# 0  Priyang   98.0     AB
# 1   Aadhya   99.0     AB
# 2   Krisha   99.0     AA
# 3   Vedant   87.0     AC
# 4   Parshv   90.0     AC
# 5   Mittal   82.0     BA
# 6  Archana   82.0     BB

# %%
# Pero se puede hacer por columnas, de derecha a izquierda
data.bfill(axis = 'columns')
# Out:
#       Name Marks Grades
# 0  Priyang  98.0    NaN
# 1   Aadhya    AB     AB
# 2   Krisha  99.0     AA
# 3   Vedant  87.0    NaN
# 4   Parshv  90.0     AC
# 5   Mittal    BA     BA
# 6  Archana  82.0     BB

# %% [markdown]
# ## Inplace

# %%
# Hace efectivos los cambios en el dataframe
df1 = pd.read_csv('data_new.csv')
df1.fillna(value = df['Temp'].mean(), inplace = True)
df1
# Out:
#               City       Temp
# 0           Tonalá  34.000000
# 1      Guadalajara  39.666667
# 2    Nueva Escocia  39.666667
# 3       Nueva York  40.000000
# 4            Delhi  39.666667
# 5  San Luis Potosí  45.000000

# %% [markdown]
# ## limit
# ## Fill the first NaN element

# %%
# Solo rellenamos el primer valor NaN que encontramos
df.ffill(limit = 1)
# Out:
#               City  Temp
# 0           Tonalá  34.0
# 1      Guadalajara  34.0
# 2    Nueva Escocia   NaN
# 3       Nueva York  40.0
# 4            Delhi  40.0
# 5  San Luis Potosí  45.0

# %%
# Solo rellenamos los primeros valores NaN que encontramos
df.ffill(limit = 2)
# Out:
#               City  Temp
# 0           Tonalá  34.0
# 1      Guadalajara  34.0
# 2    Nueva Escocia  34.0
# 3       Nueva York  40.0
# 4            Delhi  40.0
# 5  San Luis Potosí  45.0
