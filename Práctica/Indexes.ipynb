# %% [markdown]
# ## Indexes
# ## Datatype
# ## Access elements
# ## Operations

# %%
import pandas as pd

# %% [markdown]
# ### Customized Indexes

# %%
s1 = pd.Series([11, 22, 33, 44, 55], index = ['a', 'b', 'c', 'd', 'e']) # Agregamos un índice personalizado
s1
# Out:
# a    11
# b    22
# c    33
# d    44
# e    55
# dtype: int64

# %% [markdown]
# ### Datatype of serie

# %%
s1 = pd.Series([11, 22, 33, 44, 55], dtype = 'float')
s1
# Out:
# 0    11.0
# 1    22.0
# 2    33.0
# 3    44.0
# 4    55.0
# dtype: float64

# %% [markdown]
# ### Accesing data from the serie

# %%
s1 = pd.Series([11, 22, 33, 44, 55])

# %%
s1[0] # Accedemos al valor por su indice
# Out:
# np.int64(11)

# %%
s1[1]
# Out:
# np.int64(22)

# %%
s1[0:2]  # primer indice, desde donde; segundo indice, hasta cual menos 1
# Out:
# 0    11
# 1    22
# dtype: int64

# %%
s1[1:3]
# Out:
# 1    22
# 2    33
# dtype: int64

# %% [markdown]
# ### Operations on pandas series

# %%
s1 = pd.Series([1, 2, 3, 4])
s2 = pd.Series([10, 20, 30, 40])

# %%
# Suma
s1 + s2
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64

# %%
# Resta
s2 - s1
# Out:
# 0     9
# 1    18
# 2    27
# 3    36
# dtype: int64

# %%
# Multiplicación
s1 * s2
# Out:
# 0     10
# 1     40
# 2     90
# 3    160
# dtype: int64

# %%
# División
s1 / s2
# Out:
# 0    0.1
# 1    0.1
# 2    0.1
# 3    0.1
# dtype: float64

# %%
# Exponente
s1**2
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# dtype: int64

# %%
# Cuando las series no contiene la misma cantidad de elementos (Not a Number)
s1 = pd.Series([1, 2, 3, 4])
s2 = pd.Series([10, 20, 30])

s1 + s2
# Out:
# 0    11.0
# 1    22.0
# 2    33.0
# 3     NaN
# dtype: float64

# %% [markdown]
# ### Ejemplo

# %%
serie1 = pd.Series([1, 2, 3, 4])

serie2 = pd.Series([10, 20, 30, 40])

# %%
serie1 // serie2
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64

# %%
serie1 / serie2
# Out:
# 0    0.1
# 1    0.1
# 2    0.1
# 3    0.1
# dtype: float64
