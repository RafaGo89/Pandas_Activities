# %%
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/Municipalities_of_San_Luis_Potos%C3%AD'

# %%
# Si la página solo tiene una tabla
data = pd.read_html(url)[0]
data
# Out:
#                Name            Municipal seat Population (2020)[1]  \
#                Name            Municipal seat Population (2020)[1]
# 0         Ahualulco                 Ahualulco                18974
# 1         Alaquines                 Alaquines                 7785
# 2          Aquismón                  Aquismón                48359
# 3         Armadillo  Armadillo de los Infante                 4013
# 4          Axtla[a]         Axtla de Terrazas                32544
# ..              ...                       ...                  ...
# 56  Villa Juárez[q]              Villa Juárez                10304
# 57          Xilitla                   Xilitla                49741
# 58         Zaragoza         Villa de Zaragoza                27386
# 59  San Luis Potosí                         —              2822255
# 60           Mexico                         —            126014024
#
#    Population (2010)[9]  Change Land area[2]           \
# ...

# %%
url2 = 'https://en.wikipedia.org/wiki/List_of_banks_in_India'

# %%
# Podemos acceder a las diferentes tablas en una página web de acuerdo al indice
data = pd.read_html(url2)[2]
data
# Out:
#                 State                               Bank name  Established  \
# 0      Andhra Pradesh      Andhra Pradesh Grameena Vikas Bank         2006
# 1      Andhra Pradesh           Andhra Pragathi Grameena Bank         2006
# 2      Andhra Pradesh    Chaitanya Godavari Grameena Bank[51]         2006
# 3      Andhra Pradesh             Saptagiri Grameena Bank[52]         2006
# 4   Arunachal Pradesh        Arunachal Pradesh Rural Bank[53]         1983
# 5               Assam                Assam Gramin Vikash Bank         2006
# 6               Bihar               Dakshin Bihar Gramin Bank         2019
# 7               Bihar                 Uttar Bihar Gramin Bank         2008
# 8        Chhattisgarh      Chhattisgarh Rajya Gramin Bank[55]         2013
# 9             Gujarat              Baroda Gujarat Gramin Bank         2019
# 10            Gujarat              Saurashtra Gramin Bank[58]         1978
# ...

# %%
data = pd.read_html(url2)[1]
data
# Out:
#                    Bank name  Established                 Headquarters  \
# 0                  Axis Bank         1993          Mumbai, Maharashtra
# 1               Bandhan Bank         2015         Kolkata, West Bengal
# 2                   CSB Bank         1920             Thrissur, Kerala
# 3            City Union Bank         1904       Kumbakonam, Tamil Nadu
# 4                   DCB Bank         1930          Mumbai, Maharashtra
# 5             Dhanlaxmi Bank         1927             Thrissur, Kerala
# 6               Federal Bank         1931                Kochi, Kerala
# 7                  HDFC Bank         1994          Mumbai, Maharashtra
# 8                 ICICI Bank         1994          Mumbai, Maharashtra
# 9                  IDBI Bank         1964          Mumbai, Maharashtra
# 10           IDFC First Bank         2015          Mumbai, Maharashtra
# 11             IndusInd Bank         1994          Mumbai, Maharashtra
# ...
